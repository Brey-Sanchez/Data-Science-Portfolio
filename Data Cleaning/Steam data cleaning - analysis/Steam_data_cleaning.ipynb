# %%
import pandas as pd

# %%
# Importing the json file with the correct formart
steam_games = pd.read_json('/content/steam_games.json', 
                           orient='index').reset_index(drop='True')

steam_games.head()
# Out:
#      appid                         name  \
# 0       10               Counter-Strike
# 1  1000000                    ASCENXION
# 2  1000010                  Crown Trick
# 3  1000030  Cook, Serve, Delicious! 3?!
# 4  1000040                         细胞战争
#
#                                    short_description               developer  \
# 0  Play the world's number 1 online action game. ...                   Valve
# 1  ASCENXION is a 2D shoot 'em up game where you ...  IndigoBlue Game Studio
# 2  Enter a labyrinth that moves as you move, wher...            NEXT Studios
# 3  Cook, serve and manage your food truck as you ...     Vertigo Gaming Inc.
# 4  这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...           DoubleC Games
#
#                   publisher                                genre  \
# 0                     Valve                               Action
# 1  PsychoFlux Entertainment             Action, Adventure, Indie
# 2      Team17, NEXT Studios      Adventure, Indie, RPG, Strategy
# 3       Vertigo Gaming Inc.  Action, Indie, Simulation, Strategy
# 4             DoubleC Games    Action, Casual, Indie, Simulation
#
#                                                 tags  type  \
# 0  {'Action': 5426, 'FPS': 4831, 'Multiplayer': 3...  game
# 1  {'Shoot 'Em Up': 186, 'Metroidvania': 181, 'Bu...  game
# 2  {'Rogue-like': 268, 'Turn-Based Combat': 254, ...  game
# 3  {'Typing': 221, 'Management': 213, 'Casual': 2...  game
# 4  {'Action': 22, 'Casual': 22, 'Indie': 21, 'Sim...  game
#
#                                           categories  \
# 0  [Multi-player, Valve Anti-Cheat enabled, Onlin...
# 1  [Single-player, Partial Controller Support, St...
# 2  [Single-player, Partial Controller Support, St...
# 3  [Multi-player, Single-player, Co-op, Steam Ach...
# 4                                    [Single-player]
#
#                      owners  ...  price  initialprice  discount    ccu  \
# 0  10,000,000 .. 20,000,000  ...    999           999         0  13990
# 1               0 .. 20,000  ...    999           999         0      0
# 2        200,000 .. 500,000  ...    599          1999        70     99
# 3        100,000 .. 200,000  ...   1999          1999         0     76
# 4               0 .. 20,000  ...    199           199         0      0
#
#                                            languages  \
# 0  English, French, German, Italian, Spanish - Sp...
# 1                English, Korean, Simplified Chinese
# 2  Simplified Chinese, English, Japanese, Traditi...
# 3                                            English
# 4                                 Simplified Chinese
#
#                                          platforms release_date required_age  \
# 0    {'windows': True, 'mac': True, 'linux': True}    2000/11/1            0
# 1  {'windows': True, 'mac': False, 'linux': False}   2021/05/14            0
# 2  {'windows': True, 'mac': False, 'linux': False}   2020/10/16            0
# 3   {'windows': True, 'mac': True, 'linux': False}   2020/10/14            0
# 4  {'windows': True, 'mac': False, 'linux': False}   2019/03/30            0
#
#                              website  \
# 0
# 1
# 2
# 3  http://www.cookservedelicious.com
# 4
#
#                                         header_image
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
#
# [5 rows x 22 columns]

# %%
# Checking datatypes
steam_games.dtypes
# Out:
# appid                 int64
# name                 object
# short_description    object
# developer            object
# publisher            object
# genre                object
# tags                 object
# type                 object
# categories           object
# owners               object
# positive              int64
# negative              int64
# price                 int64
# initialprice          int64
# discount              int64
# ccu                   int64
# languages            object
# platforms            object
# release_date         object
# required_age         object
# website              object
# header_image         object
# dtype: object

# %%
# Checking datatypes with a bit more detail
steam_games.apply(lambda x: type(x[0]))
# Out:
# appid                <class 'numpy.int64'>
# name                         <class 'str'>
# short_description            <class 'str'>
# developer                    <class 'str'>
# publisher                    <class 'str'>
# genre                        <class 'str'>
# tags                        <class 'dict'>
# type                         <class 'str'>
# categories                  <class 'list'>
# owners                       <class 'str'>
# positive             <class 'numpy.int64'>
# negative             <class 'numpy.int64'>
# price                <class 'numpy.int64'>
# initialprice         <class 'numpy.int64'>
# discount             <class 'numpy.int64'>
# ccu                  <class 'numpy.int64'>
# languages                    <class 'str'>
# platforms                   <class 'dict'>
# release_date                 <class 'str'>
# required_age                 <class 'int'>
# website                      <class 'str'>
# header_image                 <class 'str'>
# dtype: object

# %%
# Checking for nulls/NAs in any of the columns
steam_games.isnull().sum()
# Out:
# appid                0
# name                 0
# short_description    0
# developer            0
# publisher            0
# genre                0
# tags                 0
# type                 0
# categories           0
# owners               0
# positive             0
# negative             0
# price                0
# initialprice         0
# discount             0
# ccu                  0
# languages            0
# platforms            0
# release_date         0
# required_age         0
# website              0
# header_image         0
# dtype: int64

# %%
# Checking empty cells
steam_games.apply(lambda x: x == '').sum()
# Out:
# appid                    0
# name                     0
# short_description       37
# developer              127
# publisher              132
# genre                  161
# tags                     0
# type                     0
# categories               0
# owners                   0
# positive                 0
# negative                 0
# price                    0
# initialprice             0
# discount                 0
# ccu                      0
# languages               11
# platforms                0
# release_date            99
# required_age             0
# website              25217
# header_image             0
# dtype: int64

# %%
# Describing all numeric columns
steam_games.describe()
# Out:
#               appid      positive       negative         price  initialprice  \
# count  5.569100e+04  5.569100e+04   55691.000000  55691.000000  55691.000000
# mean   1.025603e+06  1.470876e+03     241.837694    773.284983    797.566303
# std    5.227850e+05  3.098273e+04    5765.413762   1093.134583   1104.762478
# min    1.000000e+01  0.000000e+00       0.000000      0.000000      0.000000
# 25%    5.985400e+05  5.000000e+00       1.000000    134.000000    199.000000
# 50%    9.863500e+05  1.900000e+01       6.000000    499.000000    499.000000
# 75%    1.427945e+06  1.060000e+02      32.000000    999.000000    999.000000
# max    2.190950e+06  5.943345e+06  908515.000000  99900.000000  99900.000000
#
#            discount            ccu
# count  55691.000000   55691.000000
# mean       2.603778     138.959616
# std       12.887080    6002.067909
# min        0.000000       0.000000
# 25%        0.000000       0.000000
# 50%        0.000000       0.000000
# 75%        0.000000       1.000000
# max       90.000000  874053.000000

# %%
# There should be no duplicates in the appid column
steam_games['appid'].duplicated().sum()
# Out:
# 0

# %%
# There could be duplicate names
steam_games['name'].duplicated().sum()
# Out:
# 261

# %%
# Prices are missing the decimal separator
def correct_prices(price):
  if price != 0:
    price = str(price)
    price = price[:-2] + '.' + price[-2:]

  return float(price)

# %%
# Applying the fix to both prices columns
steam_games['price'] = steam_games['price'].apply(correct_prices)
steam_games['initialprice'] = steam_games['initialprice'].apply(correct_prices)

# %%
# Changes needed:
# Change MA 15+ to 15
# 7+ to 7, 21+ to 21
# 180 to 18
steam_games.required_age.value_counts()
# Out:
# 0         55030
# 15          264
# 18          223
# 16           38
# 17           38
# 12           32
# 13           26
# 14           10
# 10            7
# 180           4
# 6             4
# 3             3
# 8             3
# 7             2
# 5             1
# MA 15+        1
# 7+            1
# 21+           1
# 20            1
# 9             1
# 35            1
# Name: required_age, dtype: int64

# %%
steam_games.loc[steam_games.required_age == '180', 'required_age'] = '18'

# %%
# Extracting only the digits
steam_games['required_age'] = steam_games['required_age'].astype('str').str.extract('(\d+)').astype('int64')

# %%
# The release_date column should be of the datetime type
steam_games['release_date'] = pd.to_datetime(steam_games['release_date'], format='%Y/%m/%d')

# %%
# Checking for the range of dates
steam_games.release_date.describe(datetime_is_numeric=True)
# Out:
# count                            55592
# mean     2019-03-01 21:24:08.496186624
# min                1997-06-30 00:00:00
# 25%                2017-09-06 00:00:00
# 50%                2019-07-24 00:00:00
# 75%                2021-04-06 06:00:00
# max                2022-11-11 00:00:00
# Name: release_date, dtype: object

# %%
# It seems that these games don't have a public release date
steam_games.loc[steam_games['release_date'].isnull(), :].head()
# Out:
#          appid                           name  \
# 907     102500  Kingdoms of Amalur: Reckoning
# 2687   1075950  Disintegration Technical Beta
# 6041   1173590    Dominus Galaxia: KS Edition
# 9049   1269260               Artifact Foundry
# 10528  1321650           Rocket Ghost Aidan 2
#
#                                        short_description  \
# 907    The minds of New York Times bestselling author...
# 2687   Pilot a heavily armed Gravcycle and command yo...
# 6041   Dominus Galaxia is a 4X space strategy game wi...
# 9049   Artifact Foundry, a special edition of Artifac...
# 10528  Scared to play cause most(understating word) f...
#
#                         developer                    publisher  \
# 907    Big Huge Games, 38 Studios  38 Studios, Electronic Arts
# 2687         V1 Interactive, Inc.             Private Division
# 6041        StarChart-Interactive        StarChart-Interactive
# 9049                        Valve                        Valve
# 10528    Bobby Schwind, Matt Hipp                Bobby Schwind
#
#                                genre  \
# 907                      Action, RPG
# 2687                Action, Strategy
# 6041   Free to Play, Indie, Strategy
# 9049                        Strategy
# 10528       Action, Adventure, Indie
#
#                                                     tags  type  \
# 907    {'RPG': 884, 'Fantasy': 618, 'Open World': 587...  game
# 2687   {'Action': 78, 'Strategy': 78, 'FPS': 7, 'RTS'...  game
# 6041   {'Free to Play': 35, 'Strategy': 35, 'Indie': ...  game
# 9049   {'Strategy': 61, 'Card Game': 50, 'Board Game'...  game
# 10528  {'Action': 72, 'Adventure': 65, 'Action-Advent...  game
#
#                                               categories  \
# 907    [Single-player, Partial Controller Support, St...
# 2687   [Multi-player, Single-player, Full controller ...
# 6041   [Multi-player, Single-player, Co-op, Shared/Sp...
# 9049      [Multi-player, Single-player, Online PvP, PvP]
# 10528  [Single-player, Steam Achievements, Full contr...
#
#                        owners  ...  price  initialprice  discount  ccu  \
# 907    2,000,000 .. 5,000,000  ...    0.0           0.0         0   51
# 2687              0 .. 20,000  ...    0.0           0.0         0    0
# 6041              0 .. 20,000  ...    0.0           0.0         0    8
# 9049              0 .. 20,000  ...    0.0           0.0         0    5
# 10528             0 .. 20,000  ...    0.0           0.0         0    0
#
#                                                languages  \
# 907    English, French, German, Italian, Spanish - Spain
# 2687                                             English
# 6041                                             English
# 9049   English, French, Italian, German, Spanish - Sp...
# 10528                                            English
#
#                                              platforms release_date  \
# 907    {'windows': True, 'mac': False, 'linux': False}          NaT
# 2687   {'windows': True, 'mac': False, 'linux': False}          NaT
# 6041     {'windows': True, 'mac': True, 'linux': True}          NaT
# 9049     {'windows': True, 'mac': True, 'linux': True}          NaT
# 10528  {'windows': True, 'mac': False, 'linux': False}          NaT
#
#       required_age                                         website  \
# 907             15  http://www.ea.com/kingdoms-of-amalur-reckoning
# 2687             0             https://www.disintegrationgame.com/
# 6041             0                      https://dominusgalaxia.com
# 9049             0
# 10528            0                       https://gamesbybobby.com/
#
#                                             header_image
# 907    https://cdn.akamai.steamstatic.com/steam/apps/...
# 2687   https://cdn.akamai.steamstatic.com/steam/apps/...
# 6041   https://cdn.akamai.steamstatic.com/steam/apps/...
# 9049   https://cdn.akamai.steamstatic.com/steam/apps/...
# 10528  https://cdn.akamai.steamstatic.com/steam/apps/...
#
# [5 rows x 22 columns]

# %%
# Extracting the number of minimun and maximun estimated owners for each game
steam_games['min_est_owners'] = steam_games['owners'].apply(lambda x: int(x.split(' .. ')[0].replace(',', '')))
steam_games['max_est_owners'] = steam_games['owners'].apply(lambda x: int(x.split(' .. ')[1].replace(',', '')))

# %%
# Making sure that the columns have been created correctly
steam_games.loc[:5, ['owners', 'min_est_owners', 'max_est_owners']]
# Out:
#                      owners  min_est_owners  max_est_owners
# 0  10,000,000 .. 20,000,000        10000000        20000000
# 1               0 .. 20,000               0           20000
# 2        200,000 .. 500,000          200000          500000
# 3        100,000 .. 200,000          100000          200000
# 4               0 .. 20,000               0           20000
# 5        100,000 .. 200,000          100000          200000

# %%
pd.set_option('display.max_columns', None)
steam_games.head()
# Out:
#      appid                         name  \
# 0       10               Counter-Strike
# 1  1000000                    ASCENXION
# 2  1000010                  Crown Trick
# 3  1000030  Cook, Serve, Delicious! 3?!
# 4  1000040                         细胞战争
#
#                                    short_description               developer  \
# 0  Play the world's number 1 online action game. ...                   Valve
# 1  ASCENXION is a 2D shoot 'em up game where you ...  IndigoBlue Game Studio
# 2  Enter a labyrinth that moves as you move, wher...            NEXT Studios
# 3  Cook, serve and manage your food truck as you ...     Vertigo Gaming Inc.
# 4  这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...           DoubleC Games
#
#                   publisher                                genre  \
# 0                     Valve                               Action
# 1  PsychoFlux Entertainment             Action, Adventure, Indie
# 2      Team17, NEXT Studios      Adventure, Indie, RPG, Strategy
# 3       Vertigo Gaming Inc.  Action, Indie, Simulation, Strategy
# 4             DoubleC Games    Action, Casual, Indie, Simulation
#
#                                                 tags  type  \
# 0  {'Action': 5426, 'FPS': 4831, 'Multiplayer': 3...  game
# 1  {'Shoot 'Em Up': 186, 'Metroidvania': 181, 'Bu...  game
# 2  {'Rogue-like': 268, 'Turn-Based Combat': 254, ...  game
# 3  {'Typing': 221, 'Management': 213, 'Casual': 2...  game
# 4  {'Action': 22, 'Casual': 22, 'Indie': 21, 'Sim...  game
#
#                                           categories  \
# 0  [Multi-player, Valve Anti-Cheat enabled, Onlin...
# 1  [Single-player, Partial Controller Support, St...
# 2  [Single-player, Partial Controller Support, St...
# 3  [Multi-player, Single-player, Co-op, Steam Ach...
# 4                                    [Single-player]
#
#                      owners  positive  negative  price  initialprice  \
# 0  10,000,000 .. 20,000,000    201215      5199   9.99          9.99
# 1               0 .. 20,000        27         5   9.99          9.99
# 2        200,000 .. 500,000      4032       646   5.99         19.99
# 3        100,000 .. 200,000      1575       115  19.99         19.99
# 4               0 .. 20,000         0         1   1.99          1.99
#
#    discount    ccu                                          languages  \
# 0         0  13990  English, French, German, Italian, Spanish - Sp...
# 1         0      0                English, Korean, Simplified Chinese
# 2        70     99  Simplified Chinese, English, Japanese, Traditi...
# 3         0     76                                            English
# 4         0      0                                 Simplified Chinese
#
#                                          platforms release_date  required_age  \
# 0    {'windows': True, 'mac': True, 'linux': True}   2000-11-01             0
# 1  {'windows': True, 'mac': False, 'linux': False}   2021-05-14             0
# 2  {'windows': True, 'mac': False, 'linux': False}   2020-10-16             0
# 3   {'windows': True, 'mac': True, 'linux': False}   2020-10-14             0
# 4  {'windows': True, 'mac': False, 'linux': False}   2019-03-30             0
#
#                              website  \
# 0
# 1
# 2
# 3  http://www.cookservedelicious.com
# 4
#
#                                         header_image  min_est_owners  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...        10000000
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...               0
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...          200000
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...          100000
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...               0
#
#    max_est_owners
# 0        20000000
# 1           20000
# 2          500000
# 3          200000
# 4           20000

# %%
# Creating new columns for each OS so we can quickly check if a game is
# for a specific platform
steam_games = steam_games.join(steam_games['platforms'].apply(pd.Series), 
                               how='left')

steam_games.head()
# Out:
#      appid                         name  \
# 0       10               Counter-Strike
# 1  1000000                    ASCENXION
# 2  1000010                  Crown Trick
# 3  1000030  Cook, Serve, Delicious! 3?!
# 4  1000040                         细胞战争
#
#                                    short_description               developer  \
# 0  Play the world's number 1 online action game. ...                   Valve
# 1  ASCENXION is a 2D shoot 'em up game where you ...  IndigoBlue Game Studio
# 2  Enter a labyrinth that moves as you move, wher...            NEXT Studios
# 3  Cook, serve and manage your food truck as you ...     Vertigo Gaming Inc.
# 4  这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...           DoubleC Games
#
#                   publisher                                genre  \
# 0                     Valve                               Action
# 1  PsychoFlux Entertainment             Action, Adventure, Indie
# 2      Team17, NEXT Studios      Adventure, Indie, RPG, Strategy
# 3       Vertigo Gaming Inc.  Action, Indie, Simulation, Strategy
# 4             DoubleC Games    Action, Casual, Indie, Simulation
#
#                                                 tags  type  \
# 0  {'Action': 5426, 'FPS': 4831, 'Multiplayer': 3...  game
# 1  {'Shoot 'Em Up': 186, 'Metroidvania': 181, 'Bu...  game
# 2  {'Rogue-like': 268, 'Turn-Based Combat': 254, ...  game
# 3  {'Typing': 221, 'Management': 213, 'Casual': 2...  game
# 4  {'Action': 22, 'Casual': 22, 'Indie': 21, 'Sim...  game
#
#                                           categories  \
# 0  [Multi-player, Valve Anti-Cheat enabled, Onlin...
# 1  [Single-player, Partial Controller Support, St...
# 2  [Single-player, Partial Controller Support, St...
# 3  [Multi-player, Single-player, Co-op, Steam Ach...
# 4                                    [Single-player]
#
#                      owners  positive  negative  price  initialprice  \
# 0  10,000,000 .. 20,000,000    201215      5199   9.99          9.99
# 1               0 .. 20,000        27         5   9.99          9.99
# 2        200,000 .. 500,000      4032       646   5.99         19.99
# 3        100,000 .. 200,000      1575       115  19.99         19.99
# 4               0 .. 20,000         0         1   1.99          1.99
#
#    discount    ccu                                          languages  \
# 0         0  13990  English, French, German, Italian, Spanish - Sp...
# 1         0      0                English, Korean, Simplified Chinese
# 2        70     99  Simplified Chinese, English, Japanese, Traditi...
# 3         0     76                                            English
# 4         0      0                                 Simplified Chinese
#
#                                          platforms release_date  required_age  \
# 0    {'windows': True, 'mac': True, 'linux': True}   2000-11-01             0
# 1  {'windows': True, 'mac': False, 'linux': False}   2021-05-14             0
# 2  {'windows': True, 'mac': False, 'linux': False}   2020-10-16             0
# 3   {'windows': True, 'mac': True, 'linux': False}   2020-10-14             0
# 4  {'windows': True, 'mac': False, 'linux': False}   2019-03-30             0
#
#                              website  \
# 0
# 1
# 2
# 3  http://www.cookservedelicious.com
# 4
#
#                                         header_image  min_est_owners  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...        10000000
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...               0
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...          200000
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...          100000
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...               0
#
#    max_est_owners  windows    mac  linux
# 0        20000000     True   True   True
# 1           20000     True  False  False
# 2          500000     True  False  False
# 3          200000     True   True  False
# 4           20000     True  False  False

# %%
# Dropping unnecessary columns
steam_games.drop(columns=['owners', 'platforms'], inplace=True)

# %%
# Calculating the total number of reviews and the percentage of all reviews that
# are positive
steam_games['total_reviews'] = (steam_games['positive'] + steam_games['negative'])

steam_games['perc_positive_reviews'] = (steam_games['positive'] / steam_games['total_reviews']) * 100

steam_games.loc[:5, ['positive', 'negative', 'perc_positive_reviews']]
# Out:
#    positive  negative  perc_positive_reviews
# 0    201215      5199              97.481275
# 1        27         5              84.375000
# 2      4032       646              86.190680
# 3      1575       115              93.195266
# 4         0         1               0.000000
# 5      1018       462              68.783784

# %%
# Checking the distribution of the rating column
steam_games['perc_positive_reviews'].describe()
# Out:
# count    55528.000000
# mean        73.653555
# std         24.231786
# min          0.000000
# 25%         60.869565
# 50%         79.852353
# 75%         92.489041
# max        100.000000
# Name: perc_positive_reviews, dtype: float64

# %%
# Top 10 games with highest rating among those with more than 10.000 reviews
steam_games.loc[steam_games['total_reviews'] > 10000, 
                ['name', 'perc_positive_reviews']].\
                nlargest(10, 'perc_positive_reviews')
# Out:
#                                 name  perc_positive_reviews
# 35098                       Aseprite              99.327901
# 1960                    A Short Hike              99.258438
# 5029                    Senren＊Banka              99.213262
# 4123               People Playground              98.859368
# 41805                       Portal 2              98.781674
# 22438              Vampire Survivors              98.769091
# 11660           The Room 4: Old Sins              98.752878
# 3152   The Henry Stickmin Collection              98.719256
# 7845                       ULTRAKILL              98.650180
# 5066                           Hades              98.604954

# %%
# Getting a count of all genres
genres_count = dict()

for genre_list in steam_games.genre:
  for genre in genre_list.split(', '):
    if genre != '':
      if genre not in genres_count:
        genres_count[genre] = 1
      else:
        genres_count[genre] += 1

genres_count
# Out:
# {'Action': 23759,
#  'Adventure': 21431,
#  'Indie': 39681,
#  'RPG': 9534,
#  'Strategy': 10895,
#  'Simulation': 10836,
#  'Casual': 22086,
#  'Free to Play': 3393,
#  'Massively Multiplayer': 1460,
#  'Early Access': 6145,
#  'Education': 317,
#  'Racing': 2155,
#  'Sports': 2666,
#  'Animation & Modeling': 322,
#  'Utilities': 682,
#  'Audio Production': 195,
#  'Video Production': 247,
#  'Game Development': 159,
#  'Design & Illustration': 406,
#  'Software Training': 164,
#  'Web Publishing': 89,
#  'Photo Editing': 105,
#  'Accounting': 16,
#  'Violent': 168,
#  'Gore': 99,
#  'Nudity': 45,
#  'Sexual Content': 54,
#  'Movie': 1}

# %%
# Top 10 most popular genres
pd.Series(genres_count).nlargest(10)
# Out:
# Indie           39681
# Action          23759
# Casual          22086
# Adventure       21431
# Strategy        10895
# Simulation      10836
# RPG              9534
# Early Access     6145
# Free to Play     3393
# Sports           2666
# dtype: int64

# %%
# Getting a count of all tags in the dataset
tags_dict = {}

for tag_dict in steam_games['tags']:
  for key in tag_dict.keys():
    if key not in tags_dict:
      tags_dict[key] = 1
    else:
      tags_dict[key] += 1

pd.Series(tags_dict).sort_values(ascending=False)
# Out:
# Indie            36062
# Singleplayer     27344
# Action           25022
# Casual           23993
# Adventure        23150
#                  ...
# Volleyball           9
# Coding               6
# Masterpiece          4
# Tile-Matching        3
# Shop Keeper          3
# Length: 441, dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
# Getting the data in the correct format to obtain the percentage of games
# that are available for each OS
os_df = steam_games[['name', 'windows', 'mac', 'linux']]

os_df = pd.melt(os_df, id_vars='name', value_vars=['windows', 'mac', 'linux'], var_name='os',
                value_name='available')

os_df.head()
# Out:
#                           name       os  available
# 0               Counter-Strike  windows       True
# 1                    ASCENXION  windows       True
# 2                  Crown Trick  windows       True
# 3  Cook, Serve, Delicious! 3?!  windows       True
# 4                         细胞战争  windows       True

# %%
os_grouped = os_df.groupby('os').agg(perc_available=('available', 
                                     lambda x: sum(x)/len(x))).reset_index()

os_grouped
# Out:
#         os  perc_available
# 0    linux        0.151874
# 1      mac        0.229301
# 2  windows        0.999731

# %%
# % of games available for each OS
figure(figsize=(10, 8), dpi=100)

sns.set_style('darkgrid')

sns.barplot(data=os_grouped, x='os', y='perc_available',
            order=['windows', 'mac', 'linux'])

plt.title('Percentage of games that are available on each OS')
plt.xlabel('OS')
plt.ylabel('% of games available')

ticks = [x/100 for x in range(0, 125, 25)]

plt.yticks(ticks=ticks,
           labels=[str(int(x * 100)) + ' %' for x in ticks])

plt.show()

# %%
# Filtering on the initial price column to check the distribution of prices
# for games that cost 80 dollars or less
no_price_outlier = steam_games[steam_games.initialprice <= 80]

# %%
# A kernel density estimation makes it easier to see the underlying distribution,
# as a histogram would be too messy with so much data
f, ax = plt.subplots(figsize=(10, 8), dpi=100)

sns.kdeplot(data=no_price_outlier, x='initialprice', fill=True, ax=ax,
            bw_adjust=1.5)

plt.xlim((0, 80))

plt.xlabel('Launch price ($)')
plt.title('Distribution of price')

plt.show()

# %%
# Bivariate distribution of price and rating for games that have more than
# 100 reviews and cost 80 dollars or less
sns.set_style('darkgrid')

more_100_rat = steam_games.loc[(steam_games['total_reviews'] > 100) &
                               (steam_games['initialprice'] <= 80), :]

figure, ax = plt.subplots(figsize=(10, 8), dpi=100)

sns.histplot(data=more_100_rat, x='initialprice', y='perc_positive_reviews',
             cbar=True, binwidth=(5,5), binrange=[(0, 80), (0, 100)],
             stat='count', ax=ax, cbar_kws={'label': 'Number of games'})

sns.regplot(data=more_100_rat, x='initialprice', y='perc_positive_reviews',
            scatter=False, ax=ax, color='red')

plt.yticks(ticks=[x for x in range(5, 105, 5)])
plt.ylim((0, 100))
plt.xticks(ticks=[x for x in range(0, 85, 5)])
plt.xlim((0, 80))

plt.xlabel('Price at launch ($)')
plt.ylabel('% of positive ratings')

_ = plt.show()

# %%
# Creating custom categories for prices of games
steam_games['price_cat'] = pd.cut(steam_games.initialprice, 
                                  bins=[-1, 0, 20, 40, 60, steam_games.initialprice.max()],
                                  labels=['Free', 'Cheap', 'Normal', 'Expensive', 'Very Expensive'], 
                                  include_lowest=True)

steam_games.price_cat.unique()
# Out:
# ['Cheap', 'Free', 'Normal', 'Expensive', 'Very Expensive']
# Categories (5, object): ['Free' < 'Cheap' < 'Normal' < 'Expensive' < 'Very Expensive']

# %%
import numpy as np

# %%
# Relationship between price category and number of owners
price_owners = steam_games.groupby('price_cat').agg(avg_owners=('min_est_owners', np.mean)).reset_index()

# %%
# One might expect that, the lower the price, the higher the number of owners.
# Let's check that assumption
figure, ax = plt.subplots(figsize=(10, 8), dpi=100)

sns.barplot(data=price_owners, x='price_cat', y='avg_owners', color='indigo')

ticks = [x for x in range(0, 600000, 100000)]
plt.yticks(ticks=ticks,
           labels=[f'{x:,}' for x in ticks])

plt.ylabel('Average number of owners')
plt.xlabel('Price category')

plt.show()

# %%
# We are now going to analyze the evolution of the average price and average
# rating of games per year. Games with more than 100 reviews
import datetime as dt
import numpy as np

steam_games['year'] = steam_games.release_date.dt.strftime('%Y')

steam_games_filt = steam_games.loc[(steam_games['release_date'].notnull()) &
                                   (steam_games['total_reviews'] > 100), :]

# %%
# Grouping by year and calculating the averages for price and rating
month_year = steam_games_filt.groupby('year').agg(avg_price=('initialprice', np.mean),
                                                  avg_rating=('perc_positive_reviews', np.mean),
                                                  n_games=('appid', len),).\
                                                  reset_index()

month_year = month_year.loc[month_year['n_games'] >= 50, :]

month_year.sort_values('year', inplace=True)

# %%
month_year
# Out:
#     year  avg_price  avg_rating  n_games
# 9   2006   9.637647   85.164502       51
# 10  2007   7.446854   81.262057       89
# 11  2008   9.119421   80.645778      121
# 12  2009   9.542341   78.345453      252
# 13  2010   9.575052   76.492646      194
# 14  2011   9.654912   74.990020      226
# 15  2012  10.156689   76.722110      302
# 16  2013  10.933098   75.795210      439
# 17  2014   9.852237   73.114711     1167
# 18  2015   8.897473   73.741113     1476
# 19  2016   8.917874   75.248780     1853
# 20  2017   9.933536   76.496314     1807
# 21  2018  10.903401   78.294496     1785
# 22  2019  12.138019   80.228416     1701
# 23  2020  12.369574   82.269948     1901
# 24  2021  15.667269   82.667034     1644
# 25  2022  18.458355   82.807930     1173

# %%
# Evolution of rating and concurrent users for games based on price category

figure, ax = plt.subplots(figsize=(10, 8), dpi=100)

sns.lineplot(data=month_year, x='year', y='avg_price',
             label='Average price')

plt.legend(bbox_to_anchor=(0.992, 1))

sns.pointplot(data=month_year, x='year', y='avg_price',
              color='blue')

plt.ylabel('Average price of games ($)')
plt.xlabel('Year')
plt.ylim((0, 30))

plt.xticks(fontsize=10)

ax2 = plt.twinx()

sns.lineplot(data=month_year, x='year', y='avg_rating', ax=ax2,
             color='red', label='Average rating')

sns.pointplot(data=month_year, x='year', y='avg_rating', ax=ax2,
              color='red')

plt.legend(bbox_to_anchor=(1, 0.95))

plt.title('Evolution of price and rating of games by year')
plt.ylabel('Average rating (% of reviews that are positive)')
plt.ylim((0, 100))

plt.show()
